# %%
from merge import merge_csv_parts

merge_csv_parts("data", "data/merged/merged.csv")
# Out:
# Found CSV parts: ['salg_part1.csv', 'salg_part2.csv', 'salg_part3.csv', 'salg_part4.csv', 'salg_part5.csv', 'salg_part6.csv', 'salg_part7.csv', 'salg_part8.csv', 'salg_part9.csv', 'salg_part10.csv', 'salg_part11.csv', 'salg_part12.csv', 'salg_part13.csv', 'salg_part14.csv', 'salg_part15.csv', 'salg_part16.csv', 'salg_part17.csv', 'salg_part18.csv', 'salg_part19.csv', 'salg_part20.csv', 'salg_part21.csv', 'salg_part22.csv', 'salg_part23.csv', 'salg_part24.csv', 'salg_part25.csv', 'salg_part26.csv', 'salg_part27.csv', 'salg_part28.csv', 'salg_part29.csv', 'salg_part30.csv', 'salg_part31.csv', 'salg_part32.csv']
# Reading part 1: salg_part1.csv
# Reading part 2: salg_part2.csv
# Reading part 3: salg_part3.csv
# Reading part 4: salg_part4.csv
# Reading part 5: salg_part5.csv
# Reading part 6: salg_part6.csv
# Reading part 7: salg_part7.csv
# Reading part 8: salg_part8.csv
# Reading part 9: salg_part9.csv
# Reading part 10: salg_part10.csv
# Reading part 11: salg_part11.csv
# ...
