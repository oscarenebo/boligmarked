# %%
from merge import merge_csv_parts

merge_csv_parts("data", "data/merged/boliga_merged.csv")
# Out:
# Found CSV parts: ['boliga_salg_part1.csv', 'boliga_salg_part2.csv', 'boliga_salg_part3.csv', 'boliga_salg_part4.csv', 'boliga_salg_part5.csv', 'boliga_salg_part6.csv', 'boliga_salg_part7.csv', 'boliga_salg_part8.csv', 'boliga_salg_part9.csv', 'boliga_salg_part10.csv', 'boliga_salg_part11.csv', 'boliga_salg_part12.csv', 'boliga_salg_part13.csv', 'boliga_salg_part14.csv', 'boliga_salg_part15.csv', 'boliga_salg_part16.csv', 'boliga_salg_part17.csv', 'boliga_salg_part18.csv', 'boliga_salg_part19.csv', 'boliga_salg_part20.csv', 'boliga_salg_part21.csv', 'boliga_salg_part22.csv', 'boliga_salg_part23.csv', 'boliga_salg_part24.csv', 'boliga_salg_part25.csv', 'boliga_salg_part26.csv', 'boliga_salg_part27.csv', 'boliga_salg_part28.csv', 'boliga_salg_part29.csv', 'boliga_salg_part30.csv', 'boliga_salg_part31.csv', 'boliga_salg_part32.csv']
# Reading part 1: boliga_salg_part1.csv
# Reading part 2: boliga_salg_part2.csv
# Reading part 3: boliga_salg_part3.csv
# ...
